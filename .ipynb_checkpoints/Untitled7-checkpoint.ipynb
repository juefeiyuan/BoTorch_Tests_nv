# %%
import os
import tempfile
import copy
import numpy          as np
import numpy.random   as npr
import scipy.linalg   as spla
import scipy.stats    as sps
import scipy.optimize as spo
import multiprocessing
import ast
import numpy as np
import numpy.random as npr
import numpy as np
import random
import warnings
from torch.distributions import Normal
import time


import math
import scipy.linalg as spla
import scipy.optimize as spo
import scipy.stats as sps
import math
import torch
import gpytorch
from matplotlib import pyplot as plt
import functools
import sys






def target(X):
    x1 = X[0]
    x2 = X[1]
    
    result = (x2- (5.1/(4*math.pi*math.pi))*x1*x1 + (5/math.pi)*x1 - 6)**2 + 10*(1 - (1/(8*math.pi)))*torch.cos(x1) + 10
    return result






class ExactGPModel(gpytorch.models.ExactGP):
    def __init__(self, train_x, train_y, likelihood):
        super(ExactGPModel, self).__init__(train_x, train_y, likelihood)
        self.mean_module = gpytorch.means.ConstantMean()
        self.covar_module = gpytorch.kernels.ScaleKernel(gpytorch.kernels.RBFKernel(ard_num_dims = 2))
    
    def forward(self, x):
        mean_x = self.mean_module(x)
        covar_x = self.covar_module(x)
        return gpytorch.distributions.MultivariateNormal(mean_x, covar_x)
    
    

    
    
    
    
def train_GP_model(model, likelihood, train_x, train_y, training_iter = 150):


    model.train()
    likelihood.train()


    optimizer = torch.optim.Adam([
        {'params': model.parameters()}, ], lr=0.1)

    mll = gpytorch.mlls.ExactMarginalLogLikelihood(likelihood, model)

    for i in range(training_iter):
        optimizer.zero_grad()
        output = model(train_x)
        loss = -mll(output, train_y)
        loss.backward()
        optimizer.step()
        
    return model, likelihood




def EI(x, train_y, model, likelihood):

    x = x.astype(np.float32)
    x = torch.from_numpy(x)
    x = x.resize_((1,2))
    x = x.to(device)
    f_star = torch.min(train_y)

    model.eval()
    likelihood.eval()
    f_preds = model(x)
    pos_mu = f_preds.mean
    pos_var = f_preds.variance
    pos_sigma = pos_var.clamp_min(1e-9).sqrt()


    W = (f_star - pos_mu)/pos_sigma
    normal = Normal(torch.zeros_like(W), torch.ones_like(W))
    ucdf = normal.cdf(W)
    updf = torch.exp(normal.log_prob(W))
    ei = pos_sigma * (updf + W * ucdf)
    result = -ei
    result = result.cpu().detach().contiguous().double().clone().numpy()

    return result




def next_sampling_point(EI, train_y, model, likelihood, bnds, opt_method, maxiter, dtype, device, nRestart =25):


    min_value = 1000
    point_to_sample = None


    objective = functools.partial(EI, train_y = train_y,model = model, likelihood = likelihood)
    initial_points = torch.rand(nRestart, 2, dtype=dtype, device=device)*15 + torch.tensor([-5.0, 0.0], dtype=dtype, device=device)
    initial_points = initial_points.cpu()
    
    for i in range(nRestart):
        warnings.filterwarnings("ignore")
       
        initial_point = initial_points[i]
        function_to_optimize = objective

        warnings.filterwarnings("error")

        res = spo.minimize(function_to_optimize, initial_point, method = optimize_method, \
                               options={'maxiter':maxiter, 'disp': False}, bounds = bnds)  

        if res.fun < min_value:
            min_value = res.fun
            point_to_sample = res.x   
#         except:
#             continue

    point_to_sample = torch.from_numpy(point_to_sample)
    point_to_sample = point_to_sample.type(dtype)
    point_to_sample = point_to_sample.reshape(1,2)
    point_to_sample = point_to_sample.to(device)
    return point_to_sample

# %%
# device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device = torch.device('cpu')
dtype = torch.float
nRestart = 1000
optimize_method = 'SLSQP'
maxiter = 10000
d = 2
training_iter = 150
print(torch.cuda.get_device_name(device))


bnds = [np.array([-5., 10.]), np.array([ 0., 15.])]
opt_method = 'SLSQP'






# hypers = {
#     'covar_module.base_kernel.lengthscale': torch.tensor(0.3),
# }

train_x = torch.rand(10, 2, dtype=dtype, device=device)*15 + torch.tensor([-5.0, 0.0], dtype=dtype, device=device)

train_y = torch.zeros(train_x.shape[0], dtype=dtype, device=device)
for i in range(train_x.shape[0]):
    train_y[i] = target(train_x[i,:])
# Out:
# GeForce RTX 2080 Ti

# %%
iterations = 200

for i in range(iterations):
    warnings.filterwarnings('ignore')


    likelihood = gpytorch.likelihoods.GaussianLikelihood()
    model = ExactGPModel(train_x, train_y, likelihood)
    model = model.to(device)
    likelihood = likelihood.to(device)
    model, likelihood = train_GP_model(model, likelihood, train_x, train_y, training_iter)

    new_x = next_sampling_point(EI, train_y, model, likelihood, bnds, opt_method, maxiter, dtype, device, nRestart)
    new_y = target(new_x[0])
    train_x =  torch.cat((train_x, new_x), 0)
    train_y = torch.cat((train_y, new_y.reshape(1)), 0)
    
    print('The iteration number is ', i)
    print('Best value is ', train_y.min())
# Out:
# The iteration number is  0
# Best value is  tensor(5.1519, device='cuda:0')
# The iteration number is  1
# Best value is  tensor(5.1519, device='cuda:0')
# The iteration number is  2
# Best value is  tensor(5.1519, device='cuda:0')
# The iteration number is  3
# Best value is  tensor(5.1519, device='cuda:0')
# The iteration number is  4
# Best value is  tensor(5.1519, device='cuda:0')
# The iteration number is  5
# Best value is  tensor(5.1519, device='cuda:0')
# The iteration number is  6
# Best value is  tensor(5.1519, device='cuda:0')
# The iteration number is  7
# Best value is  tensor(5.1519, device='cuda:0')
# The iteration number is  8
# Best value is  tensor(5.1519, device='cuda:0')
# The iteration number is  9
# Best value is  tensor(1.9235, device='cuda:0')
# The iteration number is  10
# Best value is  tensor(0.9157, device='cuda:0')
# The iteration number is  11
# Best value is  tensor(0.9157, device='cuda:0')
# The iteration number is  12
# Best value is  tensor(0.9157, device='cuda:0')
# The iteration number is  13
# Best value is  tensor(0.9157, device='cuda:0')
# The iteration number is  14
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  15
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  16
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  17
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  18
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  19
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  20
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  21
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  22
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  23
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  24
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  25
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  26
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  27
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  28
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  29
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  30
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  31
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  32
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  33
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  34
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  35
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  36
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  37
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  38
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  39
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  40
# Best value is  tensor(0.4248, device='cuda:0')
# The iteration number is  41
# Best value is  tensor(0.4248, device='cuda:0')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-0dac59019222> in <module>
#      11     model, likelihood = train_GP_model(model, likelihood, train_x, train_y, training_iter)
#      12
# ---> 13     new_x = next_sampling_point(EI, train_y, model, likelihood, bnds, opt_method, maxiter, dtype, device, nRestart)
#      14     new_y = target(new_x[0])
#      15     train_x =  torch.cat((train_x, new_x), 0)
#
# <ipython-input-19-a4d2b48e69fa> in next_sampling_point(EI, train_y, model, likelihood, bnds, opt_method, maxiter, dtype, device, nRestart)
#     136
#     137         res = spo.minimize(function_to_optimize, initial_point, method = optimize_method, \
# --> 138                                options={'maxiter':maxiter, 'disp': False}, bounds = bnds)
#     139
#     140         if res.fun < min_value:
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     606     elif meth == 'slsqp':
#     607         return _minimize_slsqp(fun, x0, args, jac, bounds,
# --> 608                                constraints, callback=callback, **options)
#     609     elif meth == 'trust-constr':
#     610         return _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\slsqp.py in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, **unknown_options)
#     421             # Compute the derivatives of the objective function
#     422             # For some reason SLSQP wants g dimensioned to n+1
# --> 423             g = append(fprime(x), 0.0)
#     424
#     425             # Compute the normals of the constraints
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     324     def function_wrapper(*wrapper_args):
#     325         ncalls[0] += 1
# --> 326         return function(*(wrapper_args + args))
#     327
#     328     return ncalls, function_wrapper
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\slsqp.py in approx_jacobian(x, func, epsilon, *args)
#      61     for i in range(len(x0)):
#      62         dx[i] = epsilon
# ---> 63         jac[i] = (func(*((x0+dx,)+args)) - f0)/epsilon
#      64         dx[i] = 0.0
#      65
#
# ~\Anaconda3\lib\site-packages\scipy\optimize\optimize.py in function_wrapper(*wrapper_args)
#     324     def function_wrapper(*wrapper_args):
#     325         ncalls[0] += 1
# --> 326         return function(*(wrapper_args + args))
#     327
#     328     return ncalls, function_wrapper
#
# <ipython-input-19-a4d2b48e69fa> in EI(x, train_y, model, likelihood)
#      97     model.eval()
#      98     likelihood.eval()
# ---> 99     f_preds = model(x)
#     100     pos_mu = f_preds.mean
#     101     pos_var = f_preds.variance
#
# ~\Anaconda3\lib\site-packages\gpytorch\models\exact_gp.py in __call__(self, *args, **kwargs)
#     289             # Make the prediction
#     290             with settings._use_eval_tolerance():
# --> 291                 predictive_mean, predictive_covar = self.prediction_strategy.exact_prediction(full_mean, full_covar)
#     292
#     293             # Reshape predictive mean to match the appropriate event shape
#
# ~\Anaconda3\lib\site-packages\gpytorch\models\exact_prediction_strategies.py in exact_prediction(self, joint_mean, joint_covar)
#     288         return (
#     289             self.exact_predictive_mean(test_mean, test_train_covar),
# --> 290             self.exact_predictive_covar(test_test_covar, test_train_covar),
#     291         )
#     292
#
# ~\Anaconda3\lib\site-packages\gpytorch\models\exact_prediction_strategies.py in exact_predictive_covar(self, test_test_covar, test_train_covar)
#     338             test_train_covar = delazify(test_train_covar)
#     339             train_test_covar = test_train_covar.transpose(-1, -2)
# --> 340             covar_correction_rhs = train_train_covar.inv_matmul(train_test_covar)
#     341             # For efficiency
#     342             if torch.is_tensor(test_test_covar):
#
# ~\Anaconda3\lib\site-packages\gpytorch\lazy\lazy_tensor.py in inv_matmul(self, right_tensor, left_tensor)
#     926                 False,
#     927                 right_tensor,
# --> 928                 *self.representation(),
#     929             )
#     930         else:
#
# ~\Anaconda3\lib\site-packages\gpytorch\functions\_inv_matmul.py in forward(ctx, representation_tree, has_left, *args)
#      44             res = left_tensor @ res
#      45         else:
# ---> 46             solves = _solve(lazy_tsr, right_tensor)
#      47             res = solves
#      48
#
# ~\Anaconda3\lib\site-packages\gpytorch\functions\_inv_matmul.py in _solve(lazy_tsr, rhs)
#       8 def _solve(lazy_tsr, rhs):
#       9     if settings.fast_computations.solves.off() or lazy_tsr.size(-1) <= settings.max_cholesky_size.value():
# ---> 10         return lazy_tsr._cholesky()._cholesky_solve(rhs)
#      11     else:
#      12         with torch.no_grad():
#
# ~\Anaconda3\lib\site-packages\gpytorch\utils\memoize.py in g(self, *args, **kwargs)
#      32         cache_name = name if name is not None else method
#      33         if not is_in_cache(self, cache_name):
# ---> 34             add_to_cache(self, cache_name, method(self, *args, **kwargs))
#      35         return get_from_cache(self, cache_name)
#      36
#
# ~\Anaconda3\lib\site-packages\gpytorch\lazy\lazy_tensor.py in _cholesky(self)
#     404
#     405         # contiguous call is necessary here
# --> 406         cholesky = psd_safe_cholesky(evaluated_mat).contiguous()
#     407         return NonLazyTensor(cholesky)
#     408
#
# ~\Anaconda3\lib\site-packages\gpytorch\utils\cholesky.py in psd_safe_cholesky(A, upper, out, jitter)
#      19     """
#      20     try:
# ---> 21         L = torch.cholesky(A, upper=upper, out=out)
#      22         # TODO: Remove once fixed in pytorch (#16780)
#      23         if A.dim() > 2 and A.is_cuda:
#
# KeyboardInterrupt:

# %%
train_x
# Out:
# tensor([[-1.0005e+00,  1.5919e+00],
#         [-1.2078e+00,  1.4534e+01],
#         [ 6.8977e+00,  3.2996e+00],
#         [ 8.9485e+00,  1.3150e+01],
#         [ 4.6367e+00,  8.3267e+00],
#         [-2.1662e+00,  2.1950e+00],
#         [-2.8973e-01,  1.4864e+00],
#         [-4.6666e+00,  7.8917e+00],
#         [ 7.6966e+00,  1.0644e+01],
#         [ 5.6488e-01,  9.0731e+00],
#         [ 9.7747e+00,  3.6822e-01],
#         [ 9.7171e+00,  3.0843e-01],
#         [ 9.9867e+00,  4.1927e-01],
#         [ 9.9440e+00,  2.0963e-01],
#         [ 9.8483e+00,  3.6486e-01],
#         [ 9.5738e+00,  5.3680e-01],
#         [ 8.6821e+00,  4.0439e-02],
#         [ 9.8780e+00,  2.8486e-01],
#         [ 9.7852e+00,  4.6935e-01],
#         [ 9.6339e+00,  1.5820e-01],
#         [ 9.4003e+00,  3.0885e-02],
#         [ 9.6788e+00,  1.5616e-02],
#         [ 9.1335e+00,  1.2219e-01],
#         [ 9.8411e+00,  5.2616e-02],
#         [ 9.0235e+00,  8.1615e-02],
#         [ 8.1213e+00,  2.3133e-02],
#         [ 9.5482e+00,  2.0539e-01],
#         [ 8.7557e+00,  1.5571e-01],
#         [ 9.9182e+00,  1.2867e-01],
#         [ 9.6590e+00,  1.8921e-01],
#         [ 9.1837e+00,  9.0345e-02],
#         [ 9.4551e+00,  1.8245e-01],
#         [ 9.8688e+00,  1.9966e-02],
#         [ 9.3449e+00,  3.0372e-01],
#         [ 9.9217e+00,  3.0339e-01],
#         [ 9.7640e+00,  2.0488e-01],
#         [ 9.2471e+00,  1.0854e-01],
#         [ 9.6466e+00,  1.2312e-01],
#         [ 8.7413e+00,  1.6741e-02],
#         [ 8.0983e+00,  2.7441e-01],
#         [ 8.5407e+00,  1.7128e-02],
#         [ 9.9759e+00,  8.8191e-02],
#         [ 8.7865e+00,  1.1506e-02],
#         [ 9.8467e+00,  2.3930e-01],
#         [ 9.7921e+00,  3.4397e-01],
#         [ 9.2896e+00,  7.2184e-02],
#         [ 7.5799e+00,  1.1282e-01],
#         [ 8.3512e+00,  1.8930e-02],
#         [ 9.6862e+00,  3.4867e-02]], device='cuda:0')

# %%
train_y
# Out:
# tensor([ 52.7577,  54.6703,  22.3881, 123.5072,  57.2839,  66.3754,  44.0579,
#          79.2633,  96.9056,  33.5626,   6.8256,   6.6822,   8.4820,   9.1613,
#           7.4490,   4.7760,   6.4584,   8.1220,   6.4270,   6.8513,   6.2743,
#           7.8989,   5.2886,   9.0354,   5.4692,   9.9345,   6.1146,   5.7544,
#           9.3492,   6.8622,   5.4665,   5.7767,   9.4800,   4.8584,   8.4377,
#           7.5561,   5.4803,   7.1122,   6.3263,   9.3906,   7.1996,  10.1772,
#           6.1996,   8.0762,   7.0819,   5.7349,  14.1502,   8.3081,   7.8501],
#        device='cuda:0')
