# %%
import torch
import numpy as np
import math
from botorch.fit import fit_gpytorch_model
from botorch.models import SingleTaskGP
from botorch.test_functions import Branin
from gpytorch.mlls import ExactMarginalLogLikelihood
from botorch.acquisition import ExpectedImprovement
from botorch.optim import optimize_acqf

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dtype = torch.float
print(torch.cuda.get_device_name(device))

# %%
train_x = torch.rand(10, 2, dtype=dtype, device=device)*15 + torch.tensor([-5.0, 0.0], dtype=dtype, device=device)
branin = Branin()
train_obj = branin(train_x).unsqueeze(-1)

for i in range(200):
    model = SingleTaskGP(train_X=train_x, train_Y=train_obj)
    mll = ExactMarginalLogLikelihood(model.likelihood, model)
    fit_gpytorch_model(mll)
    best_value = train_obj.min()
    EI = ExpectedImprovement(model=model, best_f=best_value, maximize = False)
    new_point_analytic, _ = optimize_acqf(
        acq_function=EI,
        bounds=torch.tensor([[-5.0, 0.0] , [10.0, 15.0]], dtype=dtype, device=device),
        q=1,
        num_restarts=1000,
        raw_samples=1000,
        options={},
    )
    train_x =  torch.cat((train_x, new_point_analytic), 0)
    train_obj = torch.cat((train_obj, branin(new_point_analytic).unsqueeze(-1)), 0)
    print('The iteration number is ', i)
    print('Best value is ', train_obj.min())
# Out:
# The iteration number is  0
# Best value is  tensor(5.3932, device='cuda:0')
# The iteration number is  1
# Best value is  tensor(5.3932, device='cuda:0')
# The iteration number is  2
# Best value is  tensor(5.3932, device='cuda:0')
# The iteration number is  3
# Best value is  tensor(5.3932, device='cuda:0')
# The iteration number is  4
# Best value is  tensor(5.3932, device='cuda:0')
# The iteration number is  5
# Best value is  tensor(5.3932, device='cuda:0')
# The iteration number is  6
# Best value is  tensor(5.3932, device='cuda:0')
# The iteration number is  7
# Best value is  tensor(5.3932, device='cuda:0')
# The iteration number is  8
# Best value is  tensor(5.3932, device='cuda:0')
# The iteration number is  9
# Best value is  tensor(5.3932, device='cuda:0')
# The iteration number is  10
# Best value is  tensor(5.3932, device='cuda:0')
# The iteration number is  11
# Best value is  tensor(5.3932, device='cuda:0')
# The iteration number is  12
# Best value is  tensor(5.3932, device='cuda:0')
# The iteration number is  13
# Best value is  tensor(5.3932, device='cuda:0')
# The iteration number is  14
# Best value is  tensor(5.3932, device='cuda:0')
# The iteration number is  15
# Best value is  tensor(5.3932, device='cuda:0')
# The iteration number is  16
# Best value is  tensor(5.3932, device='cuda:0')
# The iteration number is  17
# Best value is  tensor(5.3932, device='cuda:0')
# The iteration number is  18
# Best value is  tensor(5.3932, device='cuda:0')
# The iteration number is  19
# Best value is  tensor(5.3932, device='cuda:0')
# The iteration number is  20
# Best value is  tensor(5.3932, device='cuda:0')
# The iteration number is  21
# Best value is  tensor(2.1800, device='cuda:0')
# The iteration number is  22
# Best value is  tensor(0.8405, device='cuda:0')
# The iteration number is  23
# Best value is  tensor(0.8405, device='cuda:0')
# The iteration number is  24
# Best value is  tensor(0.8405, device='cuda:0')
# The iteration number is  25
# Best value is  tensor(0.5332, device='cuda:0')
# The iteration number is  26
# Best value is  tensor(0.4512, device='cuda:0')
# The iteration number is  27
# Best value is  tensor(0.4512, device='cuda:0')
# The iteration number is  28
# Best value is  tensor(0.4455, device='cuda:0')
# The iteration number is  29
# Best value is  tensor(0.4455, device='cuda:0')
# The iteration number is  30
# Best value is  tensor(0.4455, device='cuda:0')
# The iteration number is  31
# Best value is  tensor(0.4455, device='cuda:0')
# The iteration number is  32
# Best value is  tensor(0.4395, device='cuda:0')
# The iteration number is  33
# Best value is  tensor(0.4395, device='cuda:0')
# The iteration number is  34
# Best value is  tensor(0.4395, device='cuda:0')
# The iteration number is  35
# Best value is  tensor(0.4395, device='cuda:0')
# The iteration number is  36
# Best value is  tensor(0.4395, device='cuda:0')
# The iteration number is  37
# Best value is  tensor(0.4395, device='cuda:0')
# The iteration number is  38
# Best value is  tensor(0.4395, device='cuda:0')
# The iteration number is  39
# Best value is  tensor(0.4395, device='cuda:0')
# The iteration number is  40
# Best value is  tensor(0.4395, device='cuda:0')
# The iteration number is  41
# Best value is  tensor(0.4395, device='cuda:0')
# The iteration number is  42
# Best value is  tensor(0.4395, device='cuda:0')
# The iteration number is  43
# Best value is  tensor(0.4395, device='cuda:0')
# The iteration number is  44
# Best value is  tensor(0.4020, device='cuda:0')
# The iteration number is  45
# Best value is  tensor(0.4020, device='cuda:0')
# The iteration number is  46
# Best value is  tensor(0.4020, device='cuda:0')
# The iteration number is  47
# Best value is  tensor(0.4020, device='cuda:0')
# The iteration number is  48
# Best value is  tensor(0.4020, device='cuda:0')
# The iteration number is  49
# Best value is  tensor(0.4020, device='cuda:0')
# The iteration number is  50
# Best value is  tensor(0.4020, device='cuda:0')
# The iteration number is  51
# Best value is  tensor(0.3997, device='cuda:0')
# The iteration number is  52
# Best value is  tensor(0.3997, device='cuda:0')
# The iteration number is  53
# Best value is  tensor(0.3997, device='cuda:0')
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-5-98d4f05f1141> in <module>
#      15         num_restarts=1000,
#      16         raw_samples=1000,
# ---> 17         options={},
#      18     )
#      19     train_x =  torch.cat((train_x, new_point_analytic), 0)
#
# ~\Anaconda3\lib\site-packages\botorch\optim\optimize.py in optimize_acqf(acq_function, bounds, q, num_restarts, raw_samples, options, inequality_constraints, equality_constraints, fixed_features, post_processing_func, batch_initial_conditions, return_best_only, sequential)
#     146             num_restarts=num_restarts,
#     147             raw_samples=raw_samples,
# --> 148             options=options,
#     149         )
#     150
#
# ~\Anaconda3\lib\site-packages\botorch\optim\initializers.py in gen_batch_initial_conditions(acq_function, bounds, q, num_restarts, raw_samples, options)
#      96                 while start_idx < X_rnd.shape[0]:
#      97                     end_idx = min(start_idx + batch_limit, X_rnd.shape[0])
# ---> 98                     Y_rnd_curr = acq_function(X_rnd[start_idx:end_idx])
#      99                     Y_rnd_list.append(Y_rnd_curr)
#     100                     start_idx += batch_limit
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     539             result = self._slow_forward(*input, **kwargs)
#     540         else:
# --> 541             result = self.forward(*input, **kwargs)
#     542         for hook in self._forward_hooks.values():
#     543             hook_result = hook(self, input, result)
#
# ~\Anaconda3\lib\site-packages\botorch\utils\transforms.py in decorated(cls, X)
#     139                 )
#     140             X = X if X.dim() > 2 else X.unsqueeze(0)
# --> 141             return method(cls, X)
#     142
#     143         return decorated
#
# ~\Anaconda3\lib\site-packages\botorch\acquisition\analytic.py in forward(self, X)
#     134         """
#     135         self.best_f = self.best_f.to(X)
# --> 136         posterior = self._get_posterior(X=X)
#     137         mean = posterior.mean
#     138         # deal with batch evaluation and broadcasting
#
# ~\Anaconda3\lib\site-packages\botorch\acquisition\analytic.py in _get_posterior(self, X, check_single_output)
#      60             The posterior at X.
#      61         """
# ---> 62         posterior = self.model.posterior(X)
#      63         if self.objective is not None:
#      64             # Unlike MCAcquisitionObjectives (which transform samples), this
#
# ~\Anaconda3\lib\site-packages\botorch\models\gpytorch.py in posterior(self, X, output_indices, observation_noise, **kwargs)
#     253                     X=X, original_batch_shape=self._input_batch_shape
#     254                 )
# --> 255             mvn = self(X)
#     256             if observation_noise:
#     257                 if isinstance(self.likelihood, FixedNoiseGaussianLikelihood):
#
# ~\Anaconda3\lib\site-packages\gpytorch\models\exact_gp.py in __call__(self, *args, **kwargs)
#     289             # Make the prediction
#     290             with settings._use_eval_tolerance():
# --> 291                 predictive_mean, predictive_covar = self.prediction_strategy.exact_prediction(full_mean, full_covar)
#     292
#     293             # Reshape predictive mean to match the appropriate event shape
#
# ~\Anaconda3\lib\site-packages\gpytorch\models\exact_prediction_strategies.py in exact_prediction(self, joint_mean, joint_covar)
#     287
#     288         return (
# --> 289             self.exact_predictive_mean(test_mean, test_train_covar),
#     290             self.exact_predictive_covar(test_test_covar, test_train_covar),
#     291         )
#
# ~\Anaconda3\lib\site-packages\gpytorch\models\exact_prediction_strategies.py in exact_predictive_mean(self, test_mean, test_train_covar)
#     305         # You **cannot* use addmv here, because test_train_covar may not actually be a non lazy tensor even for an exact
#     306         # GP, and using addmv requires you to delazify test_train_covar, which is obviously a huge no-no!
# --> 307         res = (test_train_covar @ self.mean_cache.unsqueeze(-1)).squeeze(-1)
#     308         res = res + test_mean
#     309         return res
#
# ~\Anaconda3\lib\site-packages\gpytorch\utils\memoize.py in g(self, *args, **kwargs)
#      32         cache_name = name if name is not None else method
#      33         if not is_in_cache(self, cache_name):
# ---> 34             add_to_cache(self, cache_name, method(self, *args, **kwargs))
#      35         return get_from_cache(self, cache_name)
#      36
#
# ~\Anaconda3\lib\site-packages\gpytorch\models\exact_prediction_strategies.py in mean_cache(self)
#     259
#     260         train_labels_offset = (self.train_labels - train_mean).unsqueeze(-1)
# --> 261         mean_cache = train_train_covar.inv_matmul(train_labels_offset).squeeze(-1)
#     262
#     263         if settings.detach_test_caches.on():
#
# ~\Anaconda3\lib\site-packages\gpytorch\lazy\lazy_tensor.py in inv_matmul(self, right_tensor, left_tensor)
#     926                 False,
#     927                 right_tensor,
# --> 928                 *self.representation(),
#     929             )
#     930         else:
#
# ~\Anaconda3\lib\site-packages\gpytorch\functions\_inv_matmul.py in forward(ctx, representation_tree, has_left, *args)
#      44             res = left_tensor @ res
#      45         else:
# ---> 46             solves = _solve(lazy_tsr, right_tensor)
#      47             res = solves
#      48
#
# ~\Anaconda3\lib\site-packages\gpytorch\functions\_inv_matmul.py in _solve(lazy_tsr, rhs)
#       8 def _solve(lazy_tsr, rhs):
#       9     if settings.fast_computations.solves.off() or lazy_tsr.size(-1) <= settings.max_cholesky_size.value():
# ---> 10         return lazy_tsr._cholesky()._cholesky_solve(rhs)
#      11     else:
#      12         with torch.no_grad():
#
# ~\Anaconda3\lib\site-packages\gpytorch\utils\memoize.py in g(self, *args, **kwargs)
#      32         cache_name = name if name is not None else method
#      33         if not is_in_cache(self, cache_name):
# ---> 34             add_to_cache(self, cache_name, method(self, *args, **kwargs))
#      35         return get_from_cache(self, cache_name)
#      36
#
# ~\Anaconda3\lib\site-packages\gpytorch\lazy\lazy_tensor.py in _cholesky(self)
#     404
#     405         # contiguous call is necessary here
# --> 406         cholesky = psd_safe_cholesky(evaluated_mat).contiguous()
#     407         return NonLazyTensor(cholesky)
#     408
#
# ~\Anaconda3\lib\site-packages\gpytorch\utils\cholesky.py in psd_safe_cholesky(A, upper, out, jitter)
#      44             except RuntimeError:
#      45                 continue
# ---> 46         raise e
#
# ~\Anaconda3\lib\site-packages\gpytorch\utils\cholesky.py in psd_safe_cholesky(A, upper, out, jitter)
#      19     """
#      20     try:
# ---> 21         L = torch.cholesky(A, upper=upper, out=out)
#      22         # TODO: Remove once fixed in pytorch (#16780)
#      23         if A.dim() > 2 and A.is_cuda:
#
# RuntimeError: cholesky_cuda: U(15,15) is zero, singular U.
